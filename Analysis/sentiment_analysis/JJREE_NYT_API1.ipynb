# %%
# Dependencies
import requests
from pprint import pprint
from config import api_key
import nltk
import time
import pandas as pd
import nltk
# nltk.download('vader_lexicon')

# from vaderSentiment import SentimentIntensityAnalyzer
# from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer
from nltk.sentiment.vader import SentimentIntensityAnalyzer #as SIA


url = "https://api.nytimes.com/svc/search/v2/articlesearch.json?"

analyser = SentimentIntensityAnalyzer()

# %%
# Search for articles that mention granola
query = "stocks"

# %%
# Build query URL
query_url = url + "api-key=" + api_key + "&q=" + query
query_url
# Out:
# 'https://api.nytimes.com/svc/search/v2/articlesearch.json?api-key=ElPKhSQkjeT9c2Wd&q=stocks'

# %%
news1=[]
query_url = """https://api.nytimes.com/svc/search/v2/articlesearch.json?page=1&q=finance&fq=news_desk:("business" "politics" "financial")&begin_date=20180101&end_date=20181231&api-key=DIsZ9hmtxpVeNzaY73EbuvWxkHyPAggk"""

articles = requests.get(query_url).json()
articles_list = [article for article in articles["response"]["docs"]]
for article in articles_list:
    news1.append([article["pub_date"], article["abstract"]])

pprint(news1)
# Out:
# [['2018-12-17T11:00:04+0000',
#   'Our columnist got quite a surprise when he sent out a query asking people '
#   'to talk to him about talking about money.'],
#  ['2018-12-19T15:44:32+0000',
#   'The Fed is widely expected to raise rates at the conclusion of its two-day '
#   'meeting on Wednesday. But all eyes are on what happens next.'],
#  ['2018-12-18T00:01:18+0000',
#   'The Malaysian government filed charges against Goldman Sachs for its role '
#   'in the 1MDB fraud, and in the United States, the bank’s lawyers held talks '
#   'with federal prosecutors.'],
#  ['2018-12-19T19:01:16+0000',
#   'Jerome H. Powell, the Fed chairman, defended the decision to raise the '
#   'benchmark rate for the fifth consecutive quarter, a move made despite '
#   'political pressure and financial market worries.'],
#  ['2018-12-18T15:00:28+0000',
#   'The United States has the opportunity to incubate technologies that could '
#   'enable a digital transnational currency of the future.'],
#  ['2018-12-17T00:51:02+0000',
#   'Now that the supermarket tabloid has admitted to prosecutors that it did '
#   'political dirty work for Donald Trump, here’s a look at its unlikely '
#   'power.'],
#  ['2018-12-14T16:54:11+0000',
#   'We define immediate annuities, fixed annuities, variable annuities and '
#   'index annuities, plus give you questions to ask salespeople. '],
#  ['2018-12-14T16:30:28+0000',
#   'Mortgage lenders are again promoting more complicated loans, which offer '
#   'benefits for wealthy borrowers but come with big drawbacks.'],
#  ['2018-12-13T15:16:04+0000',
#   'The end of the so-called quantitative easing effort is a milestone for the '
#   'euro and a signal that the European Central Bank is confident enough in the '
#   'eurozone’s health.'],
#  ['2018-12-11T10:00:09+0000',
#   'While Elizabeth Warren and Bernie Sanders would likely disavow super PACs, '
#   'candidates from donor-rich states like New York and California would face a '
#   'vexing choice and risk alienating liberals.']]

# %%
i=0
date = []
t = []
abstract = []
news = []
articles_list = []
while (i<101):
#     query_url = """https://api.nytimes.com/svc/search/v2/articlesearch.json?q=politics&fq=news_desk:("business" "politics" "financial")&page="""+str(i)+"""&begin_date=20190101&end_date=20190630&api-key=DIsZ9hmtxpVeNzaY73EbuvWxkHyPAggk"""
    query_url = """https://api.nytimes.com/svc/search/v2/articlesearch.json?q=finance&fq=news_desk:("business" "politics" "financial")&page="""+str(i)+"""&begin_date=20190101&end_date=20190630&api-key=DIsZ9hmtxpVeNzaY73EbuvWxkHyPAggk"""
#     print(query_url)
    articles = requests.get(query_url).json()
    articles_list = [article for article in articles["response"]["docs"]]
    for article in articles_list:
        news.append([article["pub_date"], article["abstract"]])
        date.append(article["pub_date"].split("T")[0])
        t.append(article["pub_date"].split("T")[1])
        abstract.append(article["abstract"])
    i= i+1
    time.sleep(6)

j=0
while (j<101):
#     query_url = """https://api.nytimes.com/svc/search/v2/articlesearch.json?q=politics&fq=news_desk:("business" "politics" "financial")&page="""+str(j)+"""&begin_date=20190701&end_date=20191119&api-key=DIsZ9hmtxpVeNzaY73EbuvWxkHyPAggk"""
    query_url = """https://api.nytimes.com/svc/search/v2/articlesearch.json?q=finance&fq=news_desk:("business" "politics" "financial")&page="""+str(j)+"""&begin_date=20190701&end_date=20191119&api-key=DIsZ9hmtxpVeNzaY73EbuvWxkHyPAggk"""
#     print(query_url)
    articles = requests.get(query_url).json()
    articles_list = [article for article in articles["response"]["docs"]]
    for article in articles_list:
        news.append([article["pub_date"], article["abstract"]])
        date.append(article["pub_date"].split("T")[0])
        t.append(article["pub_date"].split("T")[-1])
        abstract.append(article["abstract"])
    j= j+1
    time.sleep(6)
    
pprint(news)
# Out:
# [['2019-06-28T19:52:21+0000',
#   'Young adults are more likely to reside with their parents than previous '
#   'generations did, leading to a need for guidelines on how to manage the '
#   'stay.'],
#  ['2019-06-29T15:26:37+0000',
#   'Ms. Harris collected donations from 63,277 people, according to a campaign '
#   'aide. The aide said 58 percent of those donors had not contributed to her '
#   'campaign before.'],
#  ['2019-06-28T18:41:44+0000',
#   'The German bank is said to be preparing a sweeping restructuring that will '
#   'eliminate thousands of jobs and bring to an end its 20-year foray into Wall '
#   'Street.'],
#  ['2019-06-27T20:30:03+0000',
#   'The Federal Reserve said the largest banks were generally well prepared to '
#   'withstand a severe crisis, although Credit Suisse must improve its '
#   'operations.'],
#  ['2019-06-21T14:18:50+0000',
#   'Consumer advocates say the overdraft rule has helped people avoid excessive '
#   'penalties — like the cup of coffee that ends up costing $38.'],
#  ['2019-06-25T14:44:16+0000',
#   'The New Jersey senator is a gifted orator with a glittering résumé, but he '
#   'often pulls back from political infighting. The debates offer him a chance '
#   'to break out.'],
#  ['2019-06-25T23:28:01+0000',
#   'The social media company said it had signed 27 partners to its Libra '
#   'project. But executives at some of those companies said they were '
#   'approaching it warily.'],
#  ['2019-06-25T17:00:06+0000',
#   'Mr. Powell underlined the Fed’s insulation from politics and kept the door '
#   'open for interest rate cuts at a time of trade uncertainty.'],
#  ['2019-06-24T21:08:01+0000',
#   'From Lyndon Johnson to Richard Nixon, presidents have long had fraught '
#   'relationships with Fed chairs.'],
#  ['2019-06-20T11:00:06+0000',
#   'A New York hotel union is directing donations to the mayor, with an eye on '
#   'influencing the next mayor’s race in addition to the presidential contest.'],
#  ['2019-06-21T15:52:00+0000',
#   'The presidents of the St. Louis and Minneapolis branches of the Federal '
#   'Reserve want rates cut now, and even the central bank’s vice chair says '
#   'uncertainty is growing.'],
#  ['2019-06-18T03:28:20+0000',
#   'Mr. Biden revealed his campaign’s finances at a fund-raiser in New York on '
#   'Monday night. It’s more than any other candidate raised in the first '
#   'quarter of the year.'],
#  ['2019-06-19T16:13:42+0000',
#   'President Trump’s fund-raising haul for his re-election kickoff was more '
#   'than five leading Democrats raised in their first 24 hours — combined.'],
#  ['2019-06-19T20:00:20+0000',
#   'Federal authorities are focused on whether the bank complied with '
#   'anti-money-laundering laws, including in its review of transactions linked '
#   'to Jared Kushner.'],
#  ['2019-06-16T09:00:13+0000',
#   'Joe Biden, Pete Buttigieg and Kamala Harris are generating the most buzz, '
#   'but for different reasons. Hometown candidates like Kirsten Gillibrand and '
#   'Bill de Blasio are stirring less excitement.'],
#  ['2019-06-17T09:00:06+0000',
#   'Mr. Biden is betting that his widespread name recognition and early poll '
#   'results free him to focus on President Trump — and brush off his 22 '
#   'Democratic opponents.'],
#  ['2019-06-18T12:04:24+0000',
#   'President Trump is increasingly viewing international economic policy '
#   'through a narrow lens, seeing only how other countries decisions affect the '
#   'United States.'],
#  ['2019-06-17T03:59:08+0000',
#   'The exiting president of the E.C.B. famously vowed to do “whatever it '
#   'takes” to preserve the eurozone currency. It is unclear whether whoever '
#   'follows him can be counted on to do the same.'],
#  ['2019-06-14T10:00:07+0000',
#   'The cards, used mainly by consumers who have little credit history or a '
#   'poor one, haven’t been widely adopted. Amazon is now offering one.'],
#  ['2019-06-11T09:00:10+0000',
#   'New and untested players, some backed by Wall Street, have helped borrowers '
#   'pile up billions in loans. What could go wrong?'],
#  ['2019-06-11T09:00:08+0000',
#   'With zero certainty about what lies ahead, analysts are standing pat on '
#   'earnings forecasts. If they start to cut targets, stocks could be in for a '
#   'dive.'],
#  ['2019-06-10T15:46:52+0000',
#   'The sloppy screening of corporate transactions is the latest blow to the '
#   'bank’s reputation only days after its shares hit a record low.'],
#  ['2019-06-07T21:33:44+0000',
#   'The deal would resolve a case brought by customers who took out car loans '
#   'and were forced to pay for unnecessary auto insurance without their '
#   'knowledge.'],
#  ['2019-06-06T13:40:16+0000',
#   'Until recently big tech companies were seen as one of the few relatively '
#   'untainted sources of big-money donations for Democrats. Now, that’s '
#   'changing.'],
#  ['2019-06-07T11:00:06+0000',
#   'Advocates say the state-based accounts, which let disabled people work and '
#   'save money without risking the loss of government aid, could help millions '
#   'of people.'],
#  ['2019-06-06T15:48:28+0000',
#   'Seven Democrats, including the presidential candidate Elizabeth Warren, '
#   'want the Fed to examine the bank’s compliance with anti-money-laundering '
#   'laws over flagged transactions.'],
#  ['2019-06-04T22:18:54+0000',
#   'Customers with Chase credit cards received notifications informing them '
#   'their rights to sue would end unless they opted out, in writing, by Aug. '
#   '7.'],
#  ['2019-06-04T09:00:08+0000',
#   'A sampling of the changes that would be made by retirement legislation '
#   'passed by the House.'],
#  ['2019-06-03T23:45:01+0000',
#   'Peter Chernin sent an email seeking donations from entertainment power '
#   'players like Jeff Bezos, Shonda Rhimes, Tim Cook, Ari Emanuel and Ted '
#   'Sarandos.'],
#  ['2019-06-02T17:50:36+0000',
#   'Mr. Sanders held a small event at a nightclub, with tickets starting at '
#   '$27, in a bid to keep his grip on small donors.'],
#  ['2019-05-31T19:28:33+0000',
#   'The suit sheds light on concerns around donor-advised funds, which disburse '
#   'money over time but offer an immediate tax deduction.'],
#  ['2019-05-31T09:00:15+0000',
#   'We’ve got budget, retirement account, credit, information security and '
#   'insurance advice for your independent adult, college student, gap-year '
#   'taker or future soldier.'],
#  ['2019-05-31T08:39:01+0000',
#   'Stocks fell more than 6 percent in May, as threats to the global economy '
#   'seemed to proliferate by the week, with tariffs rising and talks yielding '
#   'no meaningful results.'],
#  ['2019-05-30T18:18:16+0000',
#   'A threshold of 130,000 donors will force campaigns to spend more on digital '
#   'ads they hope will go viral, an expensive redirection of resources, some '
#   'campaigns said.'],
#  ['2019-05-30T17:43:30+0000',
#   'Richard Clarida, the Fed’s vice chairman, said persistently low inflation '
#   'or worsening global economic risks could make officials reconsider their '
#   'patience.'],
#  ['2019-05-29T21:06:08+0000',
#   'The agency is using its authority under a new cybersecurity regulation to '
#   'investigate a mistake by a title insurer that revealed a trove of sensitive '
#   'data.'],
#  ['2019-05-30T14:00:04+0000',
#   'As more employers offer paid time off after childbirth, a class-action suit '
#   'has yielded a settlement in which JPMorgan has pledged equal treatment for '
#   'men and women.'],
#  ['2019-05-28T17:19:20+0000',
#   'As some inside and outside the White House call for weakening China’s links '
#   'to U.S. financial markets, e-commerce giant Alibaba is considering listing '
#   'its shares in Hong Kong.'],
#  ['2019-05-28T09:00:10+0000',
#   'Declining to hold big-dollar fund-raisers and rolling out one policy '
#   'proposal after another, Ms. Warren has strengthened her candidacy, though '
#   'questions about her financial viability remain.'],
#  ['2019-05-27T09:00:05+0000',
#   'The competitive lanes are set as candidates vie for black voters, women, '
#   'younger voters — but they are fluid. One thing seems sure: Joseph R. '
#   'Biden’s lead will be tested.'],
#  ['2019-05-24T16:17:12+0000',
#   'The number of 529 accounts has grown in the past few years. But most people '
#   'still haven’t heard of the plans or know about their tax benefits, research '
#   'shows.'],
#  ['2019-05-23T16:01:26+0000',
#   'Household finances are improving in a strong job market, but just six in 10 '
#   'adults still could cover a surprise expense without selling something or '
#   'borrowing money.'],
#  ['2019-05-23T14:24:22+0000',
#   'At its annual shareholders meeting, the bank’s chairman faced pressure to '
#   'resign amid a money-laundering scandal and meager profits.'],
#  ['2019-05-22T20:29:26+0000',
#   'A federal judge rejected President Trump’s efforts to block banks from '
#   'complying with congressional subpoenas, and New York lawmakers voted to let '
#   'Congress obtain his state tax returns.'],
#  ['2019-05-22T13:44:34+0000',
#   'The bank’s acknowledgment that faulty software had been used to screen '
#   'transactions for suspicious activity came a day before executives prepared '
#   'to face restive investors at an annual meeting.'],
#  ['2019-05-22T18:42:49+0000',
#   'Federal Reserve officials said they were committed to a “patient approach,” '
#   'even if the economy strengthened, and some were worried about persistently '
#   'low inflation.'],
#  ['2019-05-21T09:00:12+0000',
#   'While some of the 2020 Democrats have sworn off big donors, Joe Biden and '
#   'his campaign have welcomed them into the fold.'],
#  ['2019-05-21T19:00:08+0000',
#   'Judy Shelton, a longtime Fed critic who favors gradually taking interest '
#   'rates to zero, is being considered for a seat on the board of governors.'],
#  ['2019-05-19T23:05:32+0000',
#   'When it comes to disinformation, all signs suggest the 2020 presidential '
#   'campaign will make 2016 look like a mere test run, our columnist writes.'],
#  ['2019-05-20T18:58:33+0000',
#   'Some 2.75 trillion points and miles are earned each year, with many more '
#   'options on where to spend them. Airline tickets and hotel rooms may be the '
#   'best choices.'],
#  ['2019-05-19T16:01:05+0000',
#   'Anti-money-laundering specialists proposed filing “suspicious activity '
#   'reports” about transactions connected to President Trump and Jared Kushner. '
#   'Bank managers said no.'],
#  ['2019-05-17T15:32:25+0000',
#   'The New York senator is mired near the bottom of most polls but hopes to '
#   'jump-start her campaign and fund-raising as she aggressively criticizes '
#   'anti-abortion laws in Alabama and other states.'],
#  ['2019-05-17T14:22:31+0000',
#   'The rates, which will take effect on July 1, won’t make a big difference in '
#   'monthly payments. But given the cost of college, one expert says, “this is '
#   'a bit of good news.”'],
#  ['2019-05-17T13:00:04+0000',
#   'Offering the chance of outsize returns on the back of a huge tax break, '
#   'opportunity zones are attractive to investors. But there is a catch.'],
#  ['2019-05-15T12:28:25+0000',
#   'The authorities raided 11 offices on Wednesday as part of an investigation '
#   'into the possible concealment of capital gains in offshore companies.'],
#  ['2019-05-10T16:49:04+0000',
#   'Anything these companies can do, people can do for themselves at no cost. '
#   'Federal regulators recently filed suit against two of the biggest '
#   'companies.'],
#  ['2019-05-10T13:00:06+0000',
#   'The ability to deduct business losses against income tax is common. But '
#   'there are myriad other benefits, all legal, created specifically for '
#   'commercial real estate.'],
#  ['2019-05-09T13:30:10+0000',
#   'Each year, we ask high school seniors to submit college application essays '
#   'they’ve written about work, money, social class and related topics. Here '
#   'are five that moved us.'],
#  ['2019-05-06T15:09:48+0000',
#   'Roger Ng was arraigned in federal court in Brooklyn on Monday, just hours '
#   'after being flown back from Malaysia, where he also faces charges.'],
#  ['2019-05-04T11:52:00+0000',
#   'Tens of thousands of shareholders attended the annual meeting of Warren '
#   'Buffett’s Berkshire Hathaway. DealBook provided analysis through it all.'],
#  ['2019-05-03T18:20:15+0000',
#   'Despite low inflation and White House cajoling, Fed officials continued to '
#   'suggest a path of inaction on interest rates.'],
#  ['2019-05-03T14:29:12+0000',
#   'The Federal Trade Commission says it has seen fraudulent calls from Social '
#   'Security impostors “skyrocket,” overtaking fake I.R.S. calls.'],
#  ['2019-05-02T22:44:35+0000',
#   'The territory and a group of unsecured creditors brought their complaint '
#   'against dozens of financial firms, including some of the country’s biggest '
#   'banks.'],
#  ['2019-05-02T16:44:59+0000',
#   'Ms. Warren has hired about 50 people in Iowa, giving her a head start at '
#   'organizing for next year’s caucuses. But it’s a strategy loaded with risk.'],
#  ['2019-04-30T18:47:38+0000',
#   'President Trump and Deutsche Bank had a long, symbiotic relationship. Now, '
#   'Mr. Trump is racing to prevent the bank from sharing his financial '
#   'information with Congress.'],
#  ['2019-04-30T09:00:13+0000',
#   'In amassing a small fortune, the South Bend mayor has had the backing of an '
#   'exuberant L.G.B.T. donor base. But relying on wealthy contributors carries '
#   'political risk.'],
#  ['2019-04-26T14:53:47+0000',
#   'Just 17 states require high school students to complete a personal finance '
#   'course. But more states may soon join them.'],
#  ['2019-04-27T09:00:09+0000',
#   'Mr. Sanders’s campaign kicked off its national organizing program Saturday '
#   'with what it says are roughly 5,000 events across every state.'],
#  ['2019-04-26T20:57:56+0000',
#   'Mr. Buttigieg will now refuse contributions from federal lobbyists and will '
#   'return $30,250 to 39 individuals, his campaign said.'],
#  ['2019-04-26T18:31:29+0000',
#   'Mr. Biden raised more in his first 24 hours than any other candidate, '
#   'easing concerns among some supporters over his ability to raise money.'],
#  ['2019-04-26T20:07:22+0000',
#   'Philanthropic experts said they were not shocked by what seemed like an '
#   'ungrateful response to the money raised to restore the cathedral, but few '
#   'agreed on a solution.'],
#  ['2019-04-25T09:03:24+0000',
#   'Deutsche Bank and Commerzbank said the risks outweighed the benefits of '
#   'trying to create a mega-bank capable of taking on Wall Street giants.'],
#  ['2019-04-25T20:47:32+0000',
#   'The case was the last remaining government lawsuit against the bank over '
#   'financial crisis-era issues.'],
#  ['2019-04-23T12:00:06+0000',
#   'Mr. Biden, ahead in the polls but behind financially, is seeking out top '
#   'money bundlers, but that risks a backlash among grass-roots Democrats.'],
#  ['2019-04-20T09:00:07+0000',
#   'Interviews with several dozen Democrats show how the party, which enjoyed '
#   '2018 victories powered by female and nonwhite candidates, is grappling with '
#   'questions about race and gender in the Trump era.'],
#  ['2019-04-19T19:28:32+0000',
#   'Major Democratic donors in Pennsylvania and California are soliciting big '
#   'checks for Joe Biden, who is expected to launch his 2020 campaign next '
#   'week.'],
#  ['2019-04-19T09:00:12+0000',
#   'A proposed deal is meeting resistance from labor, regulators and some '
#   'shareholders. But there is also political momentum in Germany for a '
#   'tie-up.'],
#  ['2019-04-19T14:21:31+0000',
#   'Schools are not required to use the same terminology in their offers. And '
#   'an “award” could mean a grant — or a loan. “Celebrate,” one expert says. '
#   '“Then, decide.”'],
#  ['2019-04-19T19:17:36+0000',
#   'Divorce negotiations are never easy, and they became more complicated this '
#   'year, thanks to the tax overhaul. Here are four tips for taxpayers to '
#   'consider.'],
#  ['2019-04-17T23:14:12+0000',
#   'The Trump administration cut off the central bank’s access to United States '
#   'currency and limited its ability to conduct international financial '
#   'transactions.'],
#  ['2019-04-17T22:10:44+0000',
#   'JPMorgan gave more responsibilities to Marianne Lake and Jennifer Piepszak, '
#   'making both top contenders to eventually succeed its chief executive, Jamie '
#   'Dimon.'],
#  ['2019-04-17T20:10:17+0000',
#   'In business, in a relationship or in any big project, you have to focus '
#   'here before you focus there.'],
#  ['2019-04-17T09:00:11+0000',
#   '“The Lehman Trilogy” is a theatrical panorama of the firm’s history and '
#   'collapse. Lehman descendants and onetime employees have taken a keen '
#   'interest.'],
#  ['2019-04-17T02:21:23+0000',
#   'New figures suggest the Chinese slowdown is bottoming out. Credit goes to a '
#   'wave of lending, but economists warn that debt-fueled growth can’t '
#   'continue.'],
#  ['2019-04-17T00:16:44+0000',
#   'Senator Elizabeth Warren has spent millions to build her campaign staff, '
#   'while Mayor Pete Buttigieg spent less than 10 percent of what he raised in '
#   'the first quarter.'],
#  ['2019-04-16T15:29:41+0000',
#   'Bernie Sanders is the money leader. Elizabeth Warren is spending big. Pete '
#   'Buttigieg emerged out of nowhere. And (almost) everyone is buying gobs of '
#   'Facebook ads.'],
#  ['2019-04-15T21:39:40+0000',
#   'Presidential campaigns were required to disclose their finances for the '
#   'first quarter of the year by Monday night, a key moment in the early days '
#   'of the race.'],
#  ['2019-04-15T22:13:52+0000',
#   'Subpoenas from the House’s Financial Services and Intelligence committees '
#   'were the latest attempts by congressional Democrats to collect information '
#   'about the finances of President Trump.'],
#  ['2019-04-15T19:37:55+0000',
#   'With so many start-ups listing their shares this year, each is trying to '
#   'avoid the traffic jam to get its own moment in the sun.'],
#  ['2019-04-15T00:11:21+0000',
#   'Mr. Trump’s haul is about the size of what Senators Bernie Sanders and '
#   'Kamala Harris — the top two Democratic fund-raisers — raised combined in '
#   'the first quarter.'],
#  ['2019-04-14T17:03:58+0000',
#   'The total for Ms. Gillibrand, announced after many rivals disclosed their '
#   'numbers, trails the amounts raised by the other five senators currently '
#   'running for president.'],
#  ['2019-04-14T18:10:16+0000',
#   'Fewer taxpayers have received refunds so far this year, and refunds are '
#   'smaller. Now is the time to check your paycheck withholdings.'],
#  ['2019-04-12T17:44:05+0000',
#   'JPMorgan Chase and PNC Financial Services Group reported growth in the '
#   'first quarter, despite a federal government shutdown that lasted for most '
#   'of January.'],
#  ['2019-04-12T16:27:14+0000',
#   'Liability waivers, often in small type and filled with legal verbiage, have '
#   'become a part of modern life. But how enforceable are they?'],
#  ['2019-04-12T14:20:22+0000',
#   'The Social Security Administration used to mail out many more statements '
#   'each year. Now, it encourages workers to go online. A new report says '
#   'millions haven’t looked.'],
#  ['2019-04-11T10:13:44+0000',
#   'The chiefs of seven huge American banks testified on Capitol Hill '
#   'yesterday, and talked regulation, Russia, recession and more.'],
#  ['2019-04-10T18:25:20+0000',
#   'Amid political turmoil, a blueprint by President Recep Tayyip Erdogan’s '
#   'government avoids the tougher steps economists say are needed to reverse a '
#   'recession.'],
#  ['2019-04-10T14:00:32+0000',
#   'Ms. Warren’s total lagged what several other Democratic presidential '
#   'candidates received in the first quarter of the year, but she had a strong '
#   'finish to the quarter.'],
#  ['2019-04-10T18:00:45+0000',
#   'A simple rule that bolsters the banking system — “know your customer” — '
#   'could help combat fake news and hate speech online if companies like '
#   'Facebook and Twitter embraced it.'],
#  ['2019-04-09T14:07:31+0000',
#   'A day before he was to testify before Congress, the chief executive, Brian '
#   'Moynihan, said the lowest-paid workers would earn $17 an hour starting in '
#   'May and $20 in two years.'],
#  ['2019-04-08T20:48:51+0000',
#   'The senator’s fund-raising total includes an undisclosed amount that she '
#   'could spend only in a general election campaign, not in the primary.'],
#  ['2019-04-07T17:51:50+0000',
#   'Mr. Booker’s total is among the smallest fund-raising figures to be '
#   'voluntarily disclosed so far, though it is expected to outpace others who '
#   'have not yet announced.'],
#  ['2019-04-05T21:34:58+0000',
#   'Mr. Malpass, a Wall Street veteran and a Treasury official, is a longtime '
#   'critic of the international agency’s lending practices and business model.'],
#  ['2019-04-06T10:00:04+0000',
#   'Once known for prudence, Danske Bank and Swedbank are at the vortex of '
#   'multifaceted money laundering scandals. Here’s how to make sense of them.'],
#  ['2019-04-05T13:00:05+0000',
#   'Mark Begor thinks Equifax can be the consumer-friendly credit bureau. So '
#   'where are our free credit reports, automatic credit freezes for babies and '
#   'consistent straight talk?'],
#  ['2019-04-05T09:54:37+0000',
#   'The chairman of the Swedish bank resigned a week after the chief executive '
#   'was fired, as the U.S. financial authorities investigate possible money '
#   'laundering.'],
#  ['2019-04-05T15:30:14+0000',
#   'President Trump said on Friday that he wanted another round of quantitative '
#   'easing from the central bank.'],
#  ['2019-04-05T13:00:05+0000',
#   'Fewer taxpayers than last year had filed by late March. That may be because '
#   'of the new tax law. “This is the most complicated tax season ever,” one '
#   'C.P.A. said.'],
#  ['2019-04-05T13:00:05+0000',
#   'The Republican tax overhaul has bolstered sales of private planes by '
#   'allowing buyers to deduct the cost as a business investment.'],
#  ['2019-04-04T10:00:06+0000',
#   'Guns Down America graded 15 large consumer banks on their commitment to gun '
#   'safety and their relationships to the gun industry.'],
#  ['2019-03-31T09:00:07+0000',
#   'Money is a problem for the Democratic senator, who is likely to be '
#   'substantially out-raised in the first quarter. And she’s not the fresh '
#   'candidate anymore. But much time remains.'],
#  ['2019-04-04T10:32:29+0000',
#   'The advocacy group Guns Down America graded 15 banks based on their support '
#   'for the gun industry. Most received dismal appraisals.'],
#  ['2019-04-03T17:58:14+0000',
#   'The fund-raising total is smaller than what Senators Bernie Sanders and '
#   'Kamala Harris have revealed, but Mr. O’Rourke only joined the presidential '
#   'race in mid-March.'],
#  ['2019-04-02T14:08:38+0000',
#   'The announcement puts Mr. Sanders ahead of the other Democratic '
#   'presidential candidates who have announced their first-quarter fund-raising '
#   'numbers.'],
#  ['2019-04-02T01:28:25+0000',
#   'The California senator received 218,000 contributions, and 98 percent were '
#   'under $100.'],
#  ['2019-04-01T19:41:13+0000',
#   'No one knows how the politics of Brexit will end. But the twisting road has '
#   'already cooled investment and damaged the nation’s reputation as a haven '
#   'for commerce.'],
#  ['2019-04-01T12:46:47+0000',
#   'The 37-year-old mayor of South Bend, Ind., little known just a few months '
#   'ago, has raised his political profile and online following in recent '
#   'weeks.'],
#  ['2019-03-30T09:00:06+0000',
#   'Several 2020 presidential candidates are focused on attracting small donors '
#   'to prove grass-roots appeal, but are also privately courting major donors '
#   'whose money helps pay campaign bills.'],
#  ['2019-03-29T19:24:49+0000',
#   'Filling the job held by Timothy F. Sloan, who resigned abruptly, could only '
#   'add to the troubled bank’s challenges.'],
#  ['2019-03-29T18:54:09+0000',
#   'When people buy into a development with a board or housing association, '
#   'landing in the middle of a board dispute can be a financial disaster.'],
#  ['2019-03-28T20:21:21+0000',
#   'Mr. Sloan took over as chief in 2016 as the bank dealt with the fallout of '
#   'a series of scandals. C. Allen Parker was named the interim chief '
#   'executive.'],
#  ['2019-03-28T15:19:30+0000',
#   'A JPMorgan Chase account in London was used to send roughly $900 million to '
#   'government officials involved in a scheme to profit from an offshore oil '
#   'field.'],
#  ['2019-03-26T15:22:10+0000',
#   'The California senator and 2020 presidential candidate had raised large '
#   'sums for other Democrats. Now she’s deploying her formidable online '
#   'following for herself.'],
#  ['2019-03-25T21:00:37+0000',
#   'With days until local elections, Turkey’s banking regulator accused '
#   'JPMorgan Chase and other banks of issuing “misleading and manipulative” '
#   'investment advice.'],
#  ['2019-03-22T15:34:06+0000',
#   'Wealthy people with multiple homes may try to establish residency in '
#   'lower-tax states to reduce their bill. Advisers say it’s a complicated '
#   'task.'],
#  ['2019-03-21T15:50:37+0000',
#   'On average, candidates in the 2018 midterm races spent no more than 5 '
#   'percent of their overall media budgets on digital advertising, according to '
#   'a report by Tech for Campaigns.'],
#  ['2019-03-20T10:37:41+0000',
#   'Nearly 58 percent of C.E.O.s gave over two thirds of their political '
#   'donations to Republicans.'],
#  ['2019-03-19T10:58:17+0000',
#   'The German lender courted Mr. Trump when no one else would, gave him '
#   'millions — and has dropped him more than once.'],
#  ['2019-03-18T23:35:08+0000',
#   'In the On Politics newsletter: Ms. Warren is running the campaign she '
#   'believes the country needs. But it’s hard to win in a field crowded with '
#   'political celebrities.'],
#  ['2019-03-19T07:00:05+0000',
#   'A Harvard study found that executives donate more heavily to Republicans. '
#   'But the gap is surprising.'],
#  ['2019-03-18T23:12:09+0000',
#   'New details are emerging about the long, symbiotic and at times troubled '
#   'relationship between the president and his loyal German bank.'],
#  ['2019-03-18T11:00:05+0000',
#   'He narrowly beat the first-day haul of Senator Bernie Sanders, who raised '
#   '$5.9 million after announcing his bid last month and who would go on to '
#   'raise $10 million before his first week was over.'],
#  ['2019-03-18T22:34:37+0000',
#   'Deutsche Bank’s hunger for profits and risk led it to lend Donald Trump '
#   'more than $2 billion. Once he was elected president, employees were told '
#   'not to utter his name.'],
#  ['2019-03-18T09:00:09+0000',
#   'A federal judge’s dismissal of a market manipulation case against a former '
#   'Barclays trader is further evidence of the difficulty of proving fraud when '
#   'sophisticated parties are involved.'],
#  ['2019-03-15T15:29:29+0000',
#   'Money in an H.S.A. can pay doctors or dentists. It can also be invested and '
#   'cover future costs. Still, one financial adviser said, “It is a paperwork '
#   'hassle.”'],
#  ['2019-03-15T09:00:11+0000',
#   'No need to donate buildings or pay bribes. At Boston University, Carleton, '
#   'George Washington and Wesleyan, merely paying full tuition can offer a leg '
#   'up.'],
#  ['2019-03-13T13:00:06+0000',
#   'Tara Siegel Bernard, a personal finance reporter, recommends apps for '
#   'budgeting, investments and helping little ones as young as 6 understand the '
#   'value of money.'],
#  ['2019-03-12T14:15:58+0000',
#   'Goldman Sachs helped the Malaysian fund, known as 1MDB, sell billions of '
#   'dollars of debt to investors. One of the bankers has pleaded guilty in a '
#   'fraud investigation related to the work.'],
#  ['2019-03-12T14:20:30+0000',
#   'Timothy J. Sloan testified before a House committee, the first in a parade '
#   'of bank executives summoned by Democrats.'],
#  ['2019-03-10T12:01:34+0000',
#   'The currency rules as described by the governor of China’s central bank are '
#   'practically identical to what Beijing promised in 2016.'],
#  ['2019-03-09T18:00:04+0000',
#   'Regulators have said the bank cannot grow until it fixes practices that led '
#   'to a series of sales scandals. Employees report limited progress.'],
#  ['2019-03-08T17:32:41+0000',
#   'With online banks offering certificates of deposit that pay more than 2 '
#   'percent, some experts suggest putting cash in several C.D.s with different '
#   'terms.'],
#  ['2019-03-07T13:30:09+0000',
#   'Policymakers unexpectedly reinstated a program meant to encourage banks to '
#   'lend, a sign that its concerns extend beyond the immediate region.'],
#  ['2019-03-06T13:04:17+0000',
#   'One of the top Wall Street banks unveiled a “flexible” dress code meant to '
#   'draw younger workers and sneaker-wearing Silicon Valley clients.'],
#  ['2019-03-05T21:00:09+0000',
#   'The billionaire former New York City mayor said he would not seek the '
#   'presidency, avoiding a crowded primary field that is generally to the left '
#   'of him.'],
#  ['2019-03-04T21:39:28+0000',
#   'Market-manipulation charges against Robert Bogucki were dismissed before '
#   'the jury had a chance to deliberate, which will prevent federal prosecutors '
#   'from appealing the decision.'],
#  ['2019-03-01T18:38:42+0000',
#   'From Time Inc. to a Ponzi scheme: The journey of Jordan Goodman.'],
#  ['2019-03-01T16:53:03+0000',
#   'Collectible assets can be worth millions of dollars, but surges in the '
#   'market can put desired items out of reach, while a collapse can wipe out '
#   'speculators.'],
#  ['2019-03-01T15:24:06+0000',
#   'Two financial tech start-ups are offering credit-builder loans, which also '
#   'help customers grow their savings.'],
#  ['2019-02-27T21:43:25+0000',
#   'The president’s former lawyer, Michael Cohen, testified that Donald Trump '
#   'presented documents to Deutsche Bank that “inflated” the value of his '
#   'assets.'],
#  ['2019-02-25T23:39:50+0000',
#   'Mr. Sanders started the race with the largest donor network in the 2020 '
#   'field. That list has grown substantially since then, as more than a third '
#   'of his donations came from new email addresses.'],
#  ['2019-02-25T21:11:15+0000',
#   'Amid speculation that Berlin will push a merger of Deutsche Bank and '
#   'Commerzbank to ensure Germany has one big league lender, here are the pros '
#   'and cons.'],
#  ['2019-02-25T11:30:04+0000',
#   'The Democratic senator and presidential candidate says she wants to provide '
#   'equal access to anyone who supports her, in a move that could put pressure '
#   'on rivals who accept large donations.'],
#  ['2019-02-25T17:06:59+0000',
#   'Companies keep buying huge quantities of their own shares, propelling '
#   'prices higher even as pensions, mutual funds and individuals sit on their '
#   'hands.'],
#  ['2019-02-22T20:16:41+0000',
#   'The Office of the Comptroller of the Currency said Mitsubishi-UFJ Group had '
#   'not yet fixed its long-running inability to weed out illegal transactions '
#   'at some of its branches.'],
#  ['2019-02-22T16:16:11+0000',
#   'If you get cash back from a card in exchange for purchase, that’s generally '
#   'not taxable. But, experts say, a bonus for referring a friend probably is.'],
#  ['2019-02-20T14:33:59+0000',
#   'Hedge funds and other wealthy investors are plowing money into so-called '
#   'opportunity zone funds, a creation of the 2017 tax law that provides '
#   'incentives for spending on projects in poor areas.'],
#  ['2019-02-20T20:04:15+0000',
#   'Regulators said the uproar over the Danish lender, centered on its branch '
#   'in Tallinn, had tarnished Estonia’s financial market.'],
#  ['2019-02-20T14:26:21+0000',
#   'The impressive early fund-raising haul by Mr. Sanders gives him bragging '
#   'rights in a crowded field of Democratic presidential candidates.'],
#  ['2019-02-19T19:16:56+0000',
#   'Quit the cult of busy. If you work with your head, your brain needs rest '
#   'just like a cook’s hands or a soccer player’s legs do.'],
#  ['2019-02-17T18:14:25+0000',
#   'One thing is clear about the legacy of Brexit: Financial services will be '
#   'spread across Europe, with no one city again dominating the financial arena '
#   'as London has.'],
#  ['2019-02-15T16:52:20+0000',
#   'Part of the increase in cost is the result of the “trickle-down” of luxury '
#   'features, one car expert says. Safety features are also adding to the '
#   'price.'],
#  ['2019-02-15T10:17:49+0000',
#   'Gaby Dunn, Chanel Reynolds and Vicki Robin were born decades apart. But '
#   'their books about money have a common thread: Talk about it way, way more '
#   'often.'],
#  ['2019-02-15T19:30:10+0000',
#   'Collectors offer advice on how to buy fine art, and when to sell it.'],
#  ['2019-02-15T17:33:24+0000',
#   'Michael Calvey, founder of one of the biggest and oldest investment firms '
#   'in Russia, was detained on Friday along with five other.'],
#  ['2019-02-14T21:00:04+0000',
#   'To accommodate the sprawling field, the party announced that it would hold '
#   'debates in June and July on consecutive nights, dividing candidates by '
#   'random selection.'],
#  ['2019-02-14T20:12:20+0000',
#   'Roger Ng, a deputy of the former Goldman Sachs partner Tim Leissner, will '
#   'face bribery and money-laundering charges in Brooklyn federal court.'],
#  ['2019-02-14T11:56:17+0000',
#   'The new token, each of which represent a U.S. dollar, will be used to '
#   'settle payments between the bank’s clients.'],
#  ['2019-02-14T14:21:13+0000',
#   'The firm’s new digital token, JPM Coin, is another step in Wall Street’s '
#   'evolving approach to using blockchain, the technology behind digital '
#   'currencies.'],
#  ['2019-02-11T16:02:55+0000',
#   'New data for 2018’s fourth quarter shows the British economy growing at its '
#   'slowest pace since 2012, bringing the broad impact of a no-deal split from '
#   'the European Union into sharp relief.'],
#  ['2019-02-09T14:19:07+0000',
#   'The art of inspiring online donors is very much about timing: It’s about '
#   'having a moment in the national spotlight — and then capitalizing on it. A '
#   'looming deadline helps, too.'],
#  ['2019-02-09T14:17:02+0000',
#   'A Times analysis shows that in the contest for small donors, there is a '
#   'wide gap between the haves, led by Bernie Sanders, and have-nots like Cory '
#   'Booker.'],
#  ['2019-02-08T17:17:13+0000',
#   'The sister companies, seeking to attract people without credit cards, are '
#   'eliminating a credit check and reducing the “hold” amount they temporarily '
#   'remove from a checking account.'],
#  ['2019-02-08T17:36:00+0000',
#   'Legal action among wealthy family members has created a booming business '
#   'for lawyers who specialize in estate litigation. But financial advisers say '
#   'there are ways to minimize conflict.'],
#  ['2019-02-07T23:34:48+0000',
#   'In an online post, the chief executive of Amazon said the tabloid’s owner '
#   'had used “extortion and blackmail” to try to stop his investigation into '
#   'leaked photos and text messages.'],
#  ['2019-02-07T13:08:02+0000',
#   'If approved, the merger of BB&T and SunTrust would create the sixth-biggest '
#   'bank in the U.S., large enough to compete against the country’s largest '
#   'lenders.'],
#  ['2019-02-07T11:35:55+0000',
#   'BB&T and SunTrust say they plan to join forces, in a deal that values the '
#   'combined lenders at $66 billion.'],
#  ['2019-02-07T08:14:52+0000',
#   'The big lender had been singled out for its business practices and what an '
#   'official report said was little likelihood of change under its top '
#   'executives.'],
#  ['2019-02-06T22:36:12+0000',
#   'The agency’s new director reversed course on regulations intended to '
#   'prevent borrowers from being caught in an endless cycle of short-term, high '
#   'interest loans.'],
#  ['2019-02-05T14:25:40+0000',
#   'Central banks bought 651 tonnes of gold in 2018, up 74 percent from the '
#   'year earlier. Their reasoning may be sound.'],
#  ['2019-02-05T03:55:53+0000',
#   'President Trump will unveil his choice of Mr. Malpass, the under secretary '
#   'of the Treasury for international affairs, on Wednesday, administration '
#   'officials said.'],
#  ['2019-02-02T15:50:24+0000',
#   'Donald Trump turned to the German bank, one of the few lenders willing to '
#   'do business with him, to borrow millions of dollars that would go to his '
#   'golf resort in Scotland.'],
#  ['2019-02-01T16:07:05+0000',
#   'Cutting back on nonessential spending for a month can help people pay down '
#   'credit card balances or put money in savings. At least it’s a short month.'],
#  ['2019-02-01T02:53:16+0000',
#   'The president’s campaign spent $23 million in the final quarter of 2018 as '
#   'he stumped aggressively for Republican candidates. It reported $19 million '
#   'in cash on hand.'],
#  ['2019-02-01T22:51:03+0000',
#   'The investment bank’s board adopted a provision to claw back, or reduce, '
#   'some of the pay packages they received last year, depending on the outcome '
#   'of a federal inquiry into a fraud in Malaysia.'],
#  ['2019-02-01T16:04:37+0000',
#   'Two Democrats have proposed taxing the richest Americans at a higher rate. '
#   'But if past efforts to use tax policy to target one group are a guide, they '
#   'can backfire.'],
#  ['2019-01-31T20:08:11+0000',
#   'There are consequences whether you have a savings account or a credit card '
#   '(or both).'],
#  ['2019-01-29T21:14:17+0000',
#   'The California utility’s bankruptcy filing sets up a complicated legal case '
#   'that could raise electricity rates and hurt power suppliers while '
#   'generating hundreds of millions in lawyers’ fees.'],
#  ['2019-01-28T15:54:33+0000',
#   'Did you apply for undergraduate admission for the fall 2019 semester? Did '
#   'you write an essay about money, work or social class? We’d like to read it '
#   'and perhaps publish it.'],
#  ['2019-01-25T15:22:15+0000',
#   'While the I.R.S. has said it expects refunds to be issued on schedule, the '
#   'agency is going to take a while to return to normal after the government '
#   'shutdown.'],
#  ['2019-01-24T17:49:52+0000',
#   'Mr. Ross said workers should be able to take out loans to cover their bills '
#   'because eventually they will receive back pay.'],
#  ['2019-01-23T21:09:51+0000',
#   'Shareholders haven’t been successful in holding companies accountable for '
#   'data breaches. But that changed in the first month of 2019.'],
#  ['2019-01-18T01:16:59+0000',
#   'Personal finance luminaries and everyday investors share lessons from the '
#   'late Vanguard founder. '],
#  ['2019-01-16T17:36:57+0000',
#   'With a little time, typing and easy-to-use software, you can quickly see '
#   'your financial picture much more thoroughly and better plan for the '
#   'future.'],
#  ['2019-01-17T11:48:02+0000',
#   'The BlackRock chief executive argues that businesses cannot merely have a '
#   'purpose; they must push forward on social and political issues.'],
#  ['2019-01-16T22:16:21+0000',
#   'The investment bank is campaigning to convince the authorities that a '
#   'former partner, Tim Leissner, was a master con man — and that is how the '
#   'bank became ensnared in a vast fraud.'],
#  ['2019-01-16T12:03:51+0000',
#   'Prime Minister Theresa May’s plan suffered a crushing defeat, which thrust '
#   'Britain further into political chaos. She must come up with a backup '
#   'proposal by Monday.'],
#  ['2019-01-15T23:53:48+0000',
#   'Andrea Orcel, Europe’s most famous investment banker, was poised to become '
#   'the new chief executive of Santander. But the bank refused to pay him '
#   'compensation earned at his previous post.'],
#  ['2019-01-14T19:24:00+0000',
#   'It wasn’t a new thing, for the president to go after the Amazon founder. '
#   'But it was odd to see him making nice with his onetime friend David J. '
#   'Pecker.'],
#  ['2019-01-14T22:01:10+0000',
#   'Airline cards offer free checked bags and priority boarding. But '
#   'general-use cards with travel perks are often a better choice, an analysis '
#   'found.'],
#  ['2019-01-14T17:41:32+0000',
#   'The first of the largest United States banks to report earnings for last '
#   'year’s fourth quarter warned that Fed policy and the trade war between the '
#   'United States and China were creating new risks.'],
#  ['2019-01-12T19:39:08+0000',
#   'Government shutdown fallout is hitting airports hard — also, your grocery '
#   'store. And European officials are scrambling for a Brexit backup plan.'],
#  ['2019-01-10T10:00:06+0000',
#   'With populism making a strong comeback on the left, candidates like '
#   'Elizabeth Warren are decrying billionaires who might self-finance '
#   'campaigns, like Michael R. Bloomberg.'],
#  ['2019-01-11T19:35:42+0000',
#   'The issue is not that they will run out of money. Rather, it’s figuring out '
#   'their spending — and saving — priorities.'],
#  ['2019-01-11T18:40:43+0000',
#   'The free service started after Equifax’s huge breach in 2017. Consumer '
#   'advocates suggest placing a security freeze — not a lock — on credit '
#   'files.'],
#  ['2019-01-11T11:56:45+0000',
#   'President Trump headed to the border while the White House and Congress '
#   'worked on solutions to reopen the government.'],
#  ['2019-01-07T17:47:48+0000',
#   'In a world where things often feel static, there is inherent value in '
#   'reminding yourself that you can change. Let’s call that adventure. What’s '
#   'yours?'],
#  ['2019-01-09T11:49:30+0000',
#   'As the president escalates the fight over a border wall, the government '
#   'remains partially closed, and the effects are rippling across the economy.'],
#  ['2019-01-07T23:26:25+0000',
#   'The recent volatility in the stock market can make older investors feel '
#   'vulnerable. Here are some strategies to make sure your money lasts as long '
#   'as you do.'],
#  ['2019-01-07T11:31:55+0000',
#   'American factories complain that the president’s tariffs are hurting '
#   'profits in the industrial heartland.'],
#  ['2019-01-07T08:59:59+0000',
#   'Investors have grown worried about the potential economic impact of the '
#   'trade war. Progress on talks between the United States and China could be a '
#   'catalyst for more gains.'],
#  ['2019-01-04T12:28:50+0000',
#   'The Chinese central bank’s move is intended to send a signal that Beijing '
#   'is ready to stem a slowdown that has darkened the global outlook.'],
#  ['2019-01-04T21:34:30+0000',
#   'The scandal-plagued bank could go a long way to help federal employees who '
#   'aren’t being paid during the shutdown. Why hasn’t it done more?'],
#  ['2019-01-05T10:00:05+0000',
#   'Facing billions of dollars in damages, PG&E and other utilities want '
#   'legislators to let them pass on the cost to homeowners through higher '
#   'electricity rates.'],
#  ['2019-01-04T16:35:29+0000',
#   'Democrats far outpaced Republicans in this election cycle in small '
#   'donations, mostly using a group called ActBlue. The G.O.P. has no '
#   'equivalent.'],
#  ['2019-01-04T20:07:45+0000',
#   'People change gears for all sorts of reasons — they have no other option or '
#   'they find something they love more. The successful ones are comfortable '
#   'with the risk.'],
#  ['2019-01-02T20:39:58+0000',
#   'Europe’s central bank took control of troubled Banca Carige, an '
#   'unprecedented step to manage risk as Italy’s political and economic woes '
#   'continue.'],
#  ['2019-01-02T10:00:05+0000',
#   'Democrats will move quickly to try to build grass-roots support and raise '
#   'money — two prerequisites for any candidate hoping to break out of what is '
#   'likely to be a congested pack of contenders.'],
#  ['2019-01-02T11:24:11+0000',
#   'Wall Street’s top stock pickers are expecting gains this year. But those '
#   'forecasts could be upended.'],
#  ['2019-03-13T23:29:08+0000',
#   'Hollywood stars were the headline figures facing charges. But other wealthy '
#   'parents accused of seeking an edge for their children may have careers more '
#   'easily ruined.'],
#  ['2019-03-13T10:46:20+0000',
#   'Federal prosecutors accused financial heavyweights like Bill McGlashan and '
#   'Gordon Caplan of paying to get their kids into college through fraud.'],
#  ['2019-06-07T09:00:09+0000',
#   'Treasury Secretary Steven Mnuchin will meet China’s central bank governor '
#   'in the first meeting of senior officials from the countries since trade '
#   'talks broke down.'],
#  ['2019-03-28T15:05:56+0000',
#   'Efforts to raise money had failed, prompting the company to cease all '
#   'flights on Thursday morning.'],
#  ['2019-05-16T17:03:58+0000',
#   'Craig Phillips, a former Wall Street executive who joined the Treasury '
#   'Department to try to reshape the country’s mortgage market, will depart '
#   'next month.'],
#  ['2019-05-24T18:16:40+0000',
#   'An indictment in Brooklyn says a physician and a medical consultant were '
#   'part of a network that enticed women to have surgery to bolster lawsuit '
#   'settlements.'],
#  ['2019-04-12T07:41:43+0000',
#   'The government said work on the East Coast Rail Link would resume after its '
#   'price tag, originally projected at up to $20 billion, was cut nearly in '
#   'half.'],
#  ['2019-02-07T17:47:51+0000',
#   'In an acknowledgment of possible wrongdoing by its former leader, the '
#   'French carmaker suggested he might have misused company funds for a lavish '
#   'event at Versailles.'],
#  ['2019-03-19T17:10:51+0000',
#   'A potential merger between Deutsche Bank and Commerzbank is a private '
#   'economic affair and the government should stay out of it, Chancellor Angela '
#   'Merkel said.'],
#  ['2019-05-31T15:53:34+0000',
#   'Price increases are slowing. There are more properties for sale. And '
#   'mortgage rates are low. Still, much depends on what kind of house you want, '
#   'and where.'],
#  ['2019-03-27T22:19:59+0000',
#   'The oil company’s investment in Sabic will infuse money into a Saudi '
#   'sovereign wealth fund after a planned initial public offering of Aramco '
#   'faltered.'],
#  ['2019-06-21T18:02:22+0000',
#   'Gov. Gavin Newsom’s proposal would also protect power company customers '
#   'from the kind of huge claims that have helped push Pacific Gas & Electric '
#   'into bankruptcy.'],
#  ['2019-02-13T08:56:03+0000',
#   'The board’s vote comes as Mr. Ghosn hires a star lawyer in Japan to defend '
#   'him against charges of financial wrongdoing.'],
#  ['2019-06-07T21:15:32+0000',
#   'The value of fractional real estate has long been debated. Critics see it '
#   'as a hustle, while supporters say it is a smarter way to use a vacation '
#   'home.'],
#  ['2019-01-23T17:14:31+0000',
#   'Mr. Ghosn faces charges in Japan, and his departure will allow the French '
#   'automaker to focus on mending ties with its longtime Japanese partner.'],
#  ['2019-04-30T23:18:37+0000',
#   'The company said it would add to its record returns to shareholders, most '
#   'likely fueling an intensifying debate over corporate spending.'],
#  ['2019-03-08T13:56:30+0000',
#   'The proposal regarding the country’s $1 trillion of holdings could increase '
#   'concerns among investors about the risks of owning such stocks.'],
#  ['2019-01-14T11:28:27+0000',
#   '“Don’t tell me you don’t know where the money went,” the country’s finance '
#   'minister said.'],
#  ['2019-06-28T02:27:33+0000',
#   'One of Ms. Gillibrand’s signature proposals calls for investing heavily in '
#   'maternal and child health.'],
#  ['2019-06-06T21:15:53+0000',
#   'Talks between Fiat Chrysler and Renault to create one of the world’s '
#   'largest automakers ran into a familiar problem in France: the government '
#   'itself.'],
#  ['2019-01-10T19:24:02+0000',
#   'The European Commission is investigating whether the Dutch government '
#   'illegally allowed the American sportswear maker to camouflage profits and '
#   'save billions in taxes.'],
#  ['2019-01-14T11:28:27+0000',
#   '“Don’t tell me you don’t know where the money went,” the country’s finance '
#   'minister said.'],
#  ['2019-01-10T19:20:47+0000',
#   'At the economics profession’s largest annual gathering, women said sexual '
#   'harassment, discrimination and bullying were pushing them to the sidelines '
#   'or out of the field altogether.'],
#  ['2019-04-22T18:17:23+0000',
#   'Seeking to avoid conflict-of-interest concerns, the former vice president '
#   'plans to shutter the Biden Foundation after joining the presidential '
#   'campaign.'],
#  ['2019-06-03T19:05:38+0000',
#   'With Renault’s board set to meet Tuesday to discuss a merger, France’s '
#   'finance minister wants the government to have a seat on any new board, and '
#   'Nissan spoke of a “fundamental review” of its current alliance.'],
#  ['2019-03-06T15:43:02+0000',
#   'Statistics on convictions indicate that the odds are against Mr. Ghosn in '
#   'his trial.'],
#  ['2019-03-01T17:00:58+0000',
#   'The ride-sharing company unveiled the prospectus for its initial public '
# ...
#   'with a tarnished reputation for one and jail time for the other.'],
#  ['2019-11-09T00:14:22+0000',
#   'Michael Bloomberg may join a 2020 field where some leading candidates are '
#   'railing against wealth like his. It’s complicated.'],
#  ['2019-07-18T09:00:12+0000',
#   'Democrats still don’t agree on why they lost the White House in 2016. But '
#   'the missteps of that election are dictating this one.'],
#  ['2019-10-14T10:22:19+0000',
#   'The co-working company’s board is expected to meet as soon as this '
#   'afternoon to choose a financial lifeline, after its I.P.O. fell apart last '
#   'month.'],
#  ['2019-08-23T12:44:39+0000',
#   'The president said he would raise tariffs on $250 billion worth of Chinese '
#   'imports to 30 percent and would start the next $300 billion at a rate of 15 '
#   'percent.'],
#  ['2019-07-26T09:00:11+0000',
#   'He is one of many 2020 candidates who might have had a shot in a '
#   'pre-Trumpified era — and who aren’t ready to call it quits.'],
#  ['2019-08-25T09:00:12+0000',
#   'The collapse of WOW Air, the discount airline, has damaged the country’s '
#   'tourism industry, which had lifted it from the wreckage of the 2008 '
#   'financial crisis.'],
#  ['2019-09-03T09:00:17+0000',
#   'Corey Lewandowski, President Trump’s former campaign manager, sounds a lot '
#   'like his onetime boss as he weighs a run for Senate. Some Republican state '
#   'leaders are shuddering.'],
#  ['2019-11-06T19:15:27+0000',
#   'In Virginia, Pennsylvania and Kentucky, many voters in historically '
#   'Republican suburbs supported Democratic candidates, in part because of '
#   'antipathy toward President Trump.'],
#  ['2019-11-09T16:40:13+0000',
#   'Michael R. Bloomberg is poised to enter a race that has many voters anxious '
#   'and searching for the perfect candidate. But do they need yet one more '
#   'option?'],
#  ['2019-10-01T09:00:19+0000',
#   'Proposals from Elizabeth Warren and Bernie Sanders have raised concerns '
#   'from economists and business leaders who fear the plans would sap economic '
#   'growth.'],
#  ['2019-11-01T12:38:28+0000',
#   'Ms. Warren would impose huge tax increases on businesses and billionaires '
#   'to pay for “Medicare for all,” but she said she would not raise taxes on '
#   'the middle class.'],
#  ['2019-10-12T17:17:07+0000',
#   'Mr. Gates has minimized his ties to Mr. Epstein. But a Times investigation '
#   'reveals they had a closer relationship than previously known.'],
#  ['2019-09-05T10:34:14+0000',
#   'Google agreed to pay a record $170 million fine to settle charges that its '
#   'YouTube unit violated children’s privacy. But critics think it got off '
#   'easy.'],
#  ['2019-07-22T09:00:11+0000',
#   'Voters in a part of the state that swung for Mr. Trump in 2016 have largely '
#   'overlooked his recent attacks on four congresswomen, instead focusing their '
#   'ire on Democrats.'],
#  ['2019-10-12T17:17:07+0000',
#   'Mr. Gates has minimized his ties to Mr. Epstein. But a Times investigation '
#   'reveals they had a closer relationship than previously known.'],
#  ['2019-09-05T10:34:14+0000',
#   'Google agreed to pay a record $170 million fine to settle charges that its '
#   'YouTube unit violated children’s privacy. But critics think it got off '
#   'easy.'],
#  ['2019-07-16T10:22:53+0000',
#   'President Trump says his fight with Beijing is hurting China’s economy but '
#   'generating billions for the U.S. That’s not entirely true.'],
#  ['2019-10-18T10:11:14+0000',
#   'The Facebook chief said that the social network will continue to let '
#   'political ads tout false claims, in the name of free speech.'],
#  ['2019-09-06T10:57:41+0000',
#   'The co-working company had been counting on public-market investors to '
#   'finance its global expansion. Any shrinking or delay of its public offering '
#   'would be a body blow.'],
#  ['2019-11-14T11:11:58+0000',
#   'The engines of China’s growth continue to sputter, and the threat of '
#   'further U.S. tariffs on Chinese goods could yet make the problem worse.'],
#  ['2019-08-23T10:12:20+0000',
#   'Central bankers are looking to political leaders to help keep the world’s '
#   'prosperity going. They might be waiting awhile.'],
#  ['2019-07-10T10:14:23+0000',
#   'The Commerce Department will issue licenses for American companies that '
#   'want to do business with Huawei where there is no threat to national '
#   'security.'],
#  ['2019-08-01T10:10:16+0000',
#   'The central bank cut interest rates as expected. But many traders, '
#   'President Trump and two Fed governors disagree with the direction that the '
#   'Fed is taking.'],
#  ['2019-11-08T11:00:50+0000',
#   'It would be the first time the Trump administration has agreed to remove '
#   'any of the tariffs it has placed on $360 billion worth of Chinese goods.'],
#  ['2019-10-02T10:56:22+0000',
#   'In leaked audio conversations with employees, the Facebook chief said he '
#   'would take Ms. Warren to court if she tried to break up the company.'],
#  ['2019-09-30T10:30:01+0000',
#   'The venture capitalist Fred Wilson has come up with a simple reason for the '
#   'failures of Uber and WeWork: They were spoiled by private investors.'],
#  ['2019-07-29T10:24:02+0000',
#   'Officials from the two countries are meeting this week to continue working '
#   'on a truce. But neither side seems eager for a speedy resolution.'],
#  ['2019-09-10T09:49:03+0000',
#   'As the co-working giant struggles with a cool reception to the forthcoming '
#   'stock sale, one of its biggest investors, SoftBank, reportedly wants the '
#   'deal postponed.'],
#  ['2019-08-05T10:00:26+0000',
#   'Two new shootings have forced some businesses to reflect on what they can '
#   'do.'],
#  ['2019-07-30T10:12:30+0000',
#   'A former corporate lawyer has a radical proposal for curbing corporate '
#   'America’s excesses, even if it means more legal fights for his onetime '
#   'clients.'],
#  ['2019-11-13T11:34:52+0000',
#   'In a speech at the Economic Club of New York, the president defended his '
#   'tariffs and argued that his policies could allow America’s prosperity to '
#   'continue growing.'],
#  ['2019-10-17T10:51:34+0000',
#   'The British pound surged this morning after Britain and the E.U. reached an '
#   'agreement on Brexit. But there are still serious hurdles to overcome.'],
#  ['2019-10-01T10:52:25+0000',
#   'Pierre-Olivier Bouée has resigned after revelations that the Swiss bank had '
#   'snooped on a former executive. But Credit Suisse’s C.E.O. was found not to '
#   'be involved.'],
#  ['2019-07-25T10:13:56+0000',
#   'Facebook’s huge fine, new antitrust inquiries and calls for more regulation '
#   'show that government oversight is now a fact of life for Silicon Valley.'],
#  ['2019-09-17T11:14:47+0000',
#   'The company pushed back its stock offering, reportedly after investors '
#   'remained cool to the deal. It’s another blow to the business.'],
#  ['2019-08-05T11:07:24+0000',
#   'The trade war intensified Monday, as Beijing allowed its currency to weaken '
#   'and the Treasury Department labeled China a currency manipulator.'],
#  ['2019-09-10T09:49:03+0000',
#   'As the co-working giant struggles with a cool reception to the forthcoming '
#   'stock sale, one of its biggest investors, SoftBank, reportedly wants the '
#   'deal postponed.'],
#  ['2019-08-05T10:00:26+0000',
#   'Two new shootings have forced some businesses to reflect on what they can '
#   'do.'],
#  ['2019-07-30T10:12:30+0000',
#   'A former corporate lawyer has a radical proposal for curbing corporate '
#   'America’s excesses, even if it means more legal fights for his onetime '
#   'clients.'],
#  ['2019-10-02T10:56:22+0000',
#   'In leaked audio conversations with employees, the Facebook chief said he '
#   'would take Ms. Warren to court if she tried to break up the company.'],
#  ['2019-09-30T10:30:01+0000',
#   'The venture capitalist Fred Wilson has come up with a simple reason for the '
#   'failures of Uber and WeWork: They were spoiled by private investors.'],
#  ['2019-07-29T10:24:02+0000',
#   'Officials from the two countries are meeting this week to continue working '
#   'on a truce. But neither side seems eager for a speedy resolution.'],
#  ['2019-07-15T10:39:44+0000',
#   'Chinese officials said growth in the second quarter was just 6.2 percent, '
#   'showing the limits of Beijing’s ability to juice its economy.'],
#  ['2019-10-05T15:55:31+0000',
#   'As Trump made unfounded allegations about Biden and his son, the former '
#   'vice president was torn over what to do. He now looks more vulnerable than '
#   'at any point in the campaign.'],
#  ['2019-07-14T06:30:10+0000',
#   'And why it took him until he was 33 to come out.'],
#  ['2019-09-07T09:00:18+0000',
#   'In the clash over Robert H. Bork’s nomination, Joe Biden’s moderate '
#   'instincts defined a winning strategy.'],
#  ['2019-11-12T18:56:44+0000',
#   'SoftBank poured money into start-ups that use armies of contractors. That '
#   'has upended the lives of drivers, hotel operators and real estate agents '
#   'around the world.'],
#  ['2019-10-26T09:00:14+0000',
#   'The financier Michael Milken is a major investor in a property that became '
#   'eligible for a federal tax break — after his longtime friend, Steven '
#   'Mnuchin, intervened.'],
#  ['2019-08-22T09:00:21+0000',
#   'Polling suggests that worries about the health of the economic expansion '
#   'cross party lines.'],
#  ['2019-08-11T18:14:42+0000',
#   'Tens of millions of dollars flowed among Mr. Epstein’s bank accounts and '
#   'companies. The question of where that money came from is likely to be a key '
#   'focus after his death.'],
#  ['2019-10-04T13:00:10+0000',
#   'A remarkable leak from an internal meeting shows the company is gearing up '
#   'to fight government intervention.'],
#  ['2019-08-28T21:59:40+0000',
#   'Mr. O’Donnell said his reporting hadn’t gone through MSNBC’s “rigorous '
#   'verification and standards process.” The statement was likely to provide '
#   'fuel for President Trump’s attacks on the media.'],
#  ['2019-07-22T04:01:04+0000',
#   'Britain’s currency has slumped as uncertainty grows over how and when the '
#   'U.K. will leave the European Union.'],
#  ['2019-10-07T20:39:09+0000',
#   'The foundation that owns the station abruptly scrapped local voices on '
#   'Monday while also laying off 10 of 12 employees.'],
#  ['2019-08-23T20:54:31+0000',
#   'Two congressional committees have asked Deutsche Bank and Capital One for '
#   'Trump family financial records. A judge said the fight does not have to be '
#   'all or nothing.'],
#  ['2019-11-13T21:56:25+0000',
#   'The co-working company’s losses increased sharply as it expanded ahead of a '
#   'failed initial public offering.'],
#  ['2019-10-11T19:45:07+0000',
#   'The newsroom at the tabloid intended for subway reading loses more than '
#   'half its employees as Schneps Media, a New York publisher, takes over.'],
#  ['2019-08-27T22:37:10+0000',
#   'Two House panels have issued subpoenas requesting documents related to Mr. '
#   'Trump’s businesses and more from Deutsche Bank and Capital One.'],
#  ['2019-07-26T01:45:00+0000',
#   'Mr. Epstein, charged with sex trafficking, cultivated an intimate, '
#   'yearslong relationship with Leslie Wexner — and proceeded to get '
#   'extraordinarily rich.'],
#  ['2019-08-13T21:32:11+0000',
#   'Mr. Hickenlooper, who has remained near the bottom of the Democratic field, '
#   'is in discussions to challenge Colorado’s Republican senator, Cory '
#   'Gardner.'],
#  ['2019-08-23T16:30:04+0000',
#   'The Washington governor and self-described climate candidate told us what '
#   'it was like to achieve national recognition — after leaving the '
#   'presidential race.'],
#  ['2019-09-17T09:00:14+0000',
#   'Prince Abdulaziz bin Salman was named energy minister less than a week '
#   'before an aerial attack crippled Saudi Arabia’s oil production.'],
#  ['2019-09-21T10:00:08+0000',
#   'On top of his “Medicare for all” proposal, Mr. Sanders’s new plan would '
#   'wipe out an estimated $81 billion in existing medical debt and ignore such '
#   'debt in credit scores.'],
#  ['2019-11-03T06:34:11+0000',
#   'The oil-producing giant, Saudi Arabia’s crown jewel, could become the most '
#   'valuable company in the world.'],
#  ['2019-07-06T17:15:03+0000',
#   'Joe Biden defended his record on race, highlighting his tenure with Barack '
#   'Obama, and apologized for his remarks on working with segregationists.'],
#  ['2019-09-21T10:00:08+0000',
#   'On top of his “Medicare for all” proposal, Mr. Sanders’s new plan would '
#   'wipe out an estimated $81 billion in existing medical debt and ignore such '
#   'debt in credit scores.'],
#  ['2019-07-13T09:00:13+0000',
#   'Eric Swalwell exits the race as Tom Steyer enters it, the candidates talk '
#   'equity at the Essence Festival, and Joe Biden releases his tax returns.'],
#  ['2019-11-01T11:00:08+0000',
#   'The endowment model and the 60/40 split offer different risks and returns. '
#   'Investors should examine the pros and cons before embracing either '
#   'strategy.'],
#  ['2019-10-18T14:37:45+0000',
#   'The head of California’s biggest utility, under fire over the company’s '
#   'handling of a pre-emptive power shut-off, faced scrutiny from state '
#   'regulators.'],
#  ['2019-07-09T09:00:19+0000',
#   'Using government subsidies, tax credits and zoning changes, municipal '
#   'leaders are encouraging developers to incorporate affordable housing into '
#   'mixed-use projects.'],
#  ['2019-08-11T16:41:13+0000',
#   'The airline agreed to bar employees who support or join protests from '
#   'working on flights to mainland China, though it didn’t say how they would '
#   'be identified.'],
#  ['2019-08-07T09:00:16+0000',
#   'The ride-hailing company, craving growth, is looking to public transit for '
#   'riders and revenue. Cities aren’t sure whether to welcome it.'],
#  ['2019-09-24T16:56:38+0000',
#   'The shake-up is the most significant step that the start-up, valued at '
#   'nearly $50 billion at one point, has taken to win over Wall Street after a '
#   'botched I.P.O.'],
#  ['2019-09-25T00:53:17+0000',
#   'After more than 50 years and 44 National Magazine Awards, New York finds a '
#   'home with a digital-media powerhouse.'],
#  ['2019-07-10T15:02:43+0000',
#   'The move sidelines the researcher without pay for two years, and closes his '
#   'lab, in a case that has roiled the profession.'],
#  ['2019-07-07T18:23:29+0000',
#   'Germany’s top antitrust official is urging other countries to take on '
#   'Facebook and its peers by attacking what the companies value most: data.'],
#  ['2019-08-11T16:41:13+0000',
#   'The airline agreed to bar employees who support or join protests from '
#   'working on flights to mainland China, though it didn’t say how they would '
#   'be identified.'],
#  ['2019-09-06T18:04:00+0000',
#   'L Brands, the brand’s parent company, plans to detail an overhaul next week '
#   'as it struggles with changing tastes and an embarrassing connection to the '
#   'Epstein scandal.'],
#  ['2019-10-13T17:00:10+0000',
#   'We asked all 19 Democratic presidential candidates for their views on '
#   'assault weapons, gun licensing and other policies.'],
#  ['2019-08-29T16:24:24+0000',
#   'Frustrated by the steep commissions and discounts that apps like Zomato and '
#   'Uber Eats push on restaurants, thousands have started a movement to #Logout '
#   'from them.'],
#  ['2019-08-19T10:23:43+0000',
#   'It’s by no means certain, but a certain chain of events could easily lead '
#   'to a downturn in the U.S. economy.'],
#  ['2019-10-08T10:49:37+0000',
#   'Fallout from a tweet by a Houston Rockets executive about the Hong Kong '
#   'protests has led to blowback by China’s state broadcaster and American '
#   'lawmakers.'],
#  ['2019-08-22T22:03:47+0000',
#   'Previously undisclosed documents reveal a sweeping effort by top officials '
#   'and lawyers to oust the longtime head of the N.R.A. Not only has he '
#   'remained, but he continues to influence the president.'],
#  ['2019-10-16T10:41:14+0000',
#   'Several candidates criticized Senator Elizabeth Warren’s health care '
#   'proposal and backed proposals to impose big taxes on the wealthy.'],
#  ['2019-08-29T10:30:06+0000',
#   'Global gloom has driven investors out of the stock market and toward the '
#   'traditional haven of bonds. And they’re doing great.']]

# %%
news3 = pd.DataFrame({
                    'date': date,
                    'time':t,
                    'abstract':abstract})
news3
# Out:
#             date           time  \
# 0     2019-06-28  19:52:21+0000
# 1     2019-06-29  15:26:37+0000
# 2     2019-06-28  18:41:44+0000
# 3     2019-06-27  20:30:03+0000
# 4     2019-06-21  14:18:50+0000
# ...          ...            ...
# 1040  2019-08-19  10:23:43+0000
# 1041  2019-10-08  10:49:37+0000
# 1042  2019-08-22  22:03:47+0000
# 1043  2019-10-16  10:41:14+0000
# 1044  2019-08-29  10:30:06+0000
#
#                                                abstract
# 0     Young adults are more likely to reside with th...
# 1     Ms. Harris collected donations from 63,277 peo...
# 2     The German bank is said to be preparing a swee...
# 3     The Federal Reserve said the largest banks wer...
# 4     Consumer advocates say the overdraft rule has ...
# ...                                                 ...
# 1040  It’s by no means certain, but a certain chain ...
# 1041  Fallout from a tweet by a Houston Rockets exec...
# 1042  Previously undisclosed documents reveal a swee...
# 1043  Several candidates criticized Senator Elizabet...
# 1044  Global gloom has driven investors out of the s...
#
# [1045 rows x 3 columns]

# %%
def sentiment_analyzer_scores(news):
    sentiment = []
    for sentence in news["abstract"]:
        score = analyser.polarity_scores(sentence)
        sentiment.append(score)
    return sentiment
#     print("{:-<40} {}".format(sentence, str(score)))

# %%
news3["sentiment_score"] = sentiment_analyzer_scores(news3)
news3["date"] = pd.to_datetime(news3["date"])
print(type(news3['date'][0]))
news3.sort_values(by='date')

# news2["sentiment_score"]
news3
# Out:
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
#            date           time  \
# 0    2019-06-28  19:52:21+0000
# 1    2019-06-29  15:26:37+0000
# 2    2019-06-28  18:41:44+0000
# 3    2019-06-27  20:30:03+0000
# 4    2019-06-21  14:18:50+0000
# ...         ...            ...
# 1040 2019-08-19  10:23:43+0000
# 1041 2019-10-08  10:49:37+0000
# 1042 2019-08-22  22:03:47+0000
# 1043 2019-10-16  10:41:14+0000
# 1044 2019-08-29  10:30:06+0000
#
#                                                abstract  \
# 0     Young adults are more likely to reside with th...
# 1     Ms. Harris collected donations from 63,277 peo...
# 2     The German bank is said to be preparing a swee...
# 3     The Federal Reserve said the largest banks wer...
# 4     Consumer advocates say the overdraft rule has ...
# ...                                                 ...
# 1040  It’s by no means certain, but a certain chain ...
# 1041  Fallout from a tweet by a Houston Rockets exec...
# 1042  Previously undisclosed documents reveal a swee...
# 1043  Several candidates criticized Senator Elizabet...
# 1044  Global gloom has driven investors out of the s...
#
#                                         sentiment_score
# 0     {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
# 1     {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
# 2     {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
# 3     {'neg': 0.208, 'neu': 0.497, 'pos': 0.295, 'co...
# 4     {'neg': 0.089, 'neu': 0.81, 'pos': 0.101, 'com...
# ...                                                 ...
# 1040  {'neg': 0.067, 'neu': 0.628, 'pos': 0.305, 'co...
# 1041  {'neg': 0.079, 'neu': 0.921, 'pos': 0.0, 'comp...
# 1042  {'neg': 0.0, 'neu': 0.955, 'pos': 0.045, 'comp...
# 1043  {'neg': 0.184, 'neu': 0.549, 'pos': 0.267, 'co...
# 1044  {'neg': 0.135, 'neu': 0.712, 'pos': 0.154, 'co...
#
# [1045 rows x 4 columns]

# %%
# news3.to_csv("sentiment_analysis-2019politics.csv")
news3.to_csv("sentiment_analysis-2019finance.csv")

# Users⁩ ▸ ⁨jasonree⁩ ▸ ⁨Documents⁩ ▸ ⁨GitHub⁩ ▸ ⁨Project-3⁩
